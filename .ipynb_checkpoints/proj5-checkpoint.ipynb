# %% [markdown]
# # Analysis of New York City Real Estate

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# <ul>
#     <li>[Sales Data](#sales_data)</li>
#     <ul>
#         <li>[Manhattan](#manhattan_sales_data)</li>
#         <li>[Brooklyn](#brooklyn_sales_data)</li>
#         <li>[Bronx](#bronx_sales_data)</li>
#         <li>[Queens](#queens_sales_data)</li>
#         <li>[Staten Island](#staten_island_sales_data)</li>
#         </ul>
#     <li>[Sales Volume](#sales_volume)</li>
#     <li>[AR Models](#ar_models)</li>
#         <ul>
#             <li>[Manhattan](#manhattan_ar_model)</li>
#             <li>[Brooklyn](#bk_ar_model)</li>
#             <li>[Bronx](#bx_ar_model)</li>
#         </ul>
#     <li>[ARMA Models](#arma_model)</li>
#     <li>[LSTM Models](#lstm_model)</li>
#         <ul>
#             <li>[Manhattan LSTM](#manhattan_lstm)</li>
#             <li>[Bronx LSTM](#bronx_lstm)</li>
# </ul>

# %%
# !pip3 install torch
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from statsmodels.tsa.arima_model import ARIMA
import datetime
import pmdarima as pm
from pmdarima.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import sys
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.model_selection import cross_val_score
import glob
import torch

# %%
from python_code import data_cleaner as dc
from python_code import stats_tests as stt

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from pandas.plotting import lag_plot

# %% [markdown]
# ### Sales Data <a id='sales_data'></a>

# %%
median_sale = pd.read_csv('./data/medianSalesPrice_All.csv')

# %%
median_sale = dc.create_dataframe(median_sale)

# %%
bronx_sales_data = dc.select_borough_data(median_sale,'Bronx')
manhattan_sales_data = dc.select_borough_data(median_sale,'Manhattan')
brooklyn_sales_data = dc.select_borough_data(median_sale, 'Brooklyn')
staten_island_sales_data = dc.select_borough_data(median_sale, 'Staten Island')
queens_sales_data = dc.select_borough_data(median_sale, 'Queens')

# %%
sales_data = pd.DataFrame({'Bronx' : bronx_sales_data['value'], 
             'Manhattan': manhattan_sales_data['value'], 
             "Brooklyn" : brooklyn_sales_data['value'],
             "Staten Island" : staten_island_sales_data['value'], 
             "Queens":queens_sales_data['value']})

# %%
sales_data.plot(figsize=(20,10), title='Median Sales Price')
plt.xlabel('Years')
plt.ylabel('Dollars (Millions)')
# Out:
# Text(0, 0.5, 'Dollars (Millions)')

# %% [markdown]
# <p> Looking at the graph above, we can see how the sales prices for homes in each borough have behaved. Manhattan, is the most expensive borough, with the Bronx being the least expensive.</p>

# %% [markdown]
# #### Manhattan Sales Data <a id='manhattan_sales_data'></a>

# %%
manhattan_sales_data['value'].plot()
manhattan_sales_data['value'].diff().plot(title='Manhattan Sales Data', figsize=(20,10))

# %%
dc.describe_data(manhattan_sales_data)
# Out:
# 'The lowest median asking price was $686,000 which was in the year 2010. The highest median asking price was $1,510,000 which was in the year 2019. Over the course of 9 years (between 2010 and 2019), the asking price has increased by 120.1%.'

# %%
plt.figure(figsize=(10,5))
chart = sns.distplot(manhattan_sales_data['value'])
chart.set_title('Distribution of Asking Price in Manhattan')
chart.set_xlabel('Dollars')
chart.axvline(manhattan_sales_data['value'].mean(), color = 'green')
plt.savefig('mhn_dist.png')

# %%
lag_plot(manhattan_sales_data['value'])
plt.show()

# %% [markdown]
# #### Brooklyn Sales Data <a id='brooklyn_sales_data'></a>

# %%
brooklyn_sales_data['value'].plot()
brooklyn_sales_data['value'].diff().plot(title='Brooklyn Sales Data', figsize=(20,10))

# %%
dc.describe_data(brooklyn_sales_data)
# Out:
# 'The lowest median asking price was $434,800 which was in the year 2010. The highest median asking price was $850,000 which was in the year 2019. Over the course of 9 years (between 2010 and 2019), the asking price has increased by 95.5%.'

# %%
plt.figure(figsize=(20,10))
sns.distplot(brooklyn_sales_data['value'])

# %% [markdown]
# #### Bronx Sales Data <a id='bronx_sales_data'></a>

# %%
bronx_sales_data['value'].plot()
bronx_sales_data['value'].diff().plot(title='Bronx Sales Data', figsize=(20,10))

# %%
dc.describe_data(bronx_sales_data)
# Out:
# 'The lowest median asking price was $214,300 which was in the year 2011. The highest median asking price was $542,900 which was in the year 2020. Over the course of 9 years (between 2011 and 2020), the asking price has increased by 153.3%.'

# %%
plt.figure(figsize=(10,5))
chart = sns.distplot(bronx_sales_data['value'])
chart.set_title('Distribution of Asking Price in the Bronx')
chart.set_xlabel('Dollars')
chart.axvline(bronx_sales_data['value'].mean(), color = 'green')
plt.savefig('bronx_dist.png')

# %% [markdown]
# #### Queens Sales Data <a id='queens_sales_data'></a>

# %%
queens_sales_data['value'].plot()
queens_sales_data['value'].diff().plot(title='Queens Sales Data', figsize=(20,10))

# %%
dc.describe_data(queens_sales_data)
# Out:
# 'The lowest median asking price was $334,620 which was in the year 2011. The highest median asking price was $615,000 which was in the year 2020. Over the course of 9 years (between 2011 and 2020), the asking price has increased by 83.8%.'

# %%
plt.figure(figsize=(20,10))
sns.distplot(queens_sales_data['value'])

# %% [markdown]
# #### Staten Island Sales Data <a id='staten_island_sales_data'></a>

# %%
staten_island_sales_data['value'].plot()
staten_island_sales_data['value'].diff().plot(title='Queens Sales Data', figsize=(20,10))

# %%
dc.describe_data(staten_island_sales_data)
# Out:
# 'The lowest median asking price was $345,000 which was in the year 2011. The highest median asking price was $560,000 which was in the year 2020. Over the course of 9 years (between 2011 and 2020), the asking price has increased by 62.3%.'

# %%
plt.figure(figsize=(20,10))
sns.distplot(staten_island_sales_data['value'])

# %% [markdown]
# ### Sales Volume <a id='sales_volume'></a>

# %%
data = pd.read_csv('./data/recordedSalesVolume_All.csv')

# %%
sales_volume = dc.create_dataframe(data)

# %%
manhattan_sales_volume = dc.select_borough_data(sales_volume, 'Manhattan')
bronx_sales_volume = dc.select_borough_data(sales_volume, 'Bronx')
queens_sales_volume = dc.select_borough_data(sales_volume, 'Queens')
staten_island_sales_volume = dc.select_borough_data(sales_volume, 'Staten Island')
brooklyn_sales_volume = dc.select_borough_data(sales_volume, 'Brooklyn')

# %%
sales_volume_data = pd.DataFrame({'Bronx' : bronx_sales_volume['value'], 
             'Manhattan': manhattan_sales_volume['value'], 
             "Brooklyn" : brooklyn_sales_volume['value'],
             "Staten Island" : staten_island_sales_volume['value'], 
             "Queens":queens_sales_volume['value']})

# %%
sales_volume_data.plot(figsize=(20,10), title='Sales Volume by Borough')

# %% [markdown]
# <p> As we can see with this graph, housing availability doesn't have a clear cut leader of the pack. As of about 2017, Queens seems to have the largest average number of sales. </p>

# %% [markdown]
# ### AR Models <a id='ar_models'></a>

# %% [markdown]
# #### Baseline Model - Manhattan Median Asking Price

# %%
stt.dickey_fuller_test(manhattan_sales_data['value'])
# Out:
# Test statistic = -1.497
# P-value = 0.830
# Critical values :
# 	1%: -4.039012576443273 - The data is not stationary with 99% confidence
# 	5%: -3.44903886706097 - The data is not stationary with 95% confidence
# 	10%: -3.149645684529911 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(manhattan_sales_data['value'].diff()[1:])
# Out:
# Test statistic = -6.847
# P-value = 0.000
# Critical values :
# 	1%: -4.039012576443273 - The data is  stationary with 99% confidence
# 	5%: -3.44903886706097 - The data is  stationary with 95% confidence
# 	10%: -3.149645684529911 - The data is  stationary with 90% confidence

# %%
plot_pacf(manhattan_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(bronx_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(manhattan_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
test_dates = '2018-06-01'
training_dates_start = '2010-01-01'
training_dates_end = '2018-05-01'

# %%
testing_set = manhattan_sales_data['value'][test_dates:]
training_set = manhattan_sales_data['value'][training_dates_start:training_dates_end]

# %%
stt.dickey_fuller_test(training_set.diff()[1:])
# Out:
# Test statistic = -5.861
# P-value = 0.000
# Critical values :
# 	1%: -4.0630536556927295 - The data is  stationary with 99% confidence
# 	5%: -3.4604500192043894 - The data is  stationary with 95% confidence
# 	10%: -3.156294156378601 - The data is  stationary with 90% confidence

# %%
def run_arma(series, p,q):
    mod_arma = ARMA(series, order=(p,q))
    res_arma = mod_arma.fit()
    return res_arma.summary()

# %%
run_arma(training_set,1,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(1, 0)   Log Likelihood               -1265.116
# Method:                       css-mle   S.D. of innovations          66195.763
# Date:                Wed, 19 Aug 2020   AIC                           2536.231
# Time:                        23:40:23   BIC                           2544.076
# Sample:                    01-01-2010   HQIC                          2539.407
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        9.056e+05   4.37e+04     20.701      0.000     8.2e+05    9.91e+05
# ar.L1.value     0.8577      0.051     16.788      0.000       0.758       0.958
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1659           +0.0000j            1.1659            0.0000
# -----------------------------------------------------------------------------
# """

# %%
run_arma(testing_set,1,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   25
# Model:                     ARMA(1, 0)   Log Likelihood                -327.987
# Method:                       css-mle   S.D. of innovations         120510.208
# Date:                Wed, 19 Aug 2020   AIC                            661.975
# Time:                        23:40:25   BIC                            665.631
# Sample:                    06-01-2018   HQIC                           662.989
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.066e+06   3.09e+04     34.524      0.000    1.01e+06    1.13e+06
# ar.L1.value     0.2274      0.197      1.153      0.249      -0.159       0.614
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            4.3966           +0.0000j            4.3966            0.0000
# -----------------------------------------------------------------------------
# """

# %%
test_time = pd.DataFrame(index=pd.date_range('2018-06-01', periods=22, freq='MS'))

# %%
mod_arma = ARMA(testing_set, order=(1,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 120553.7180045239

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 8.081171612013648

# %% [markdown]
# #### Model Result

# %% [markdown]
# <p>Using a First Order AR Model, that excludes the Moving Average Lags, gives an RMSE of 120553 and a SMAPE Score of 8.08 </p>

# %%
run_arma(training_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(2, 0)   Log Likelihood               -1256.556
# Method:                       css-mle   S.D. of innovations          60701.100
# Date:                Thu, 20 Aug 2020   AIC                           2521.112
# Time:                        00:30:25   BIC                           2531.572
# Sample:                    01-01-2010   HQIC                          2525.347
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        9.056e+05   6.42e+04     14.107      0.000     7.8e+05    1.03e+06
# ar.L1.value     0.5213      0.090      5.767      0.000       0.344       0.699
# ar.L2.value     0.3967      0.091      4.341      0.000       0.218       0.576
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0612           +0.0000j            1.0612            0.0000
# AR.2           -2.3755           +0.0000j            2.3755            0.5000
# -----------------------------------------------------------------------------
# """

# %%
run_arma(testing_set, 2, 0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   25
# Model:                     ARMA(2, 0)   Log Likelihood                -327.952
# Method:                       css-mle   S.D. of innovations         120325.508
# Date:                Thu, 20 Aug 2020   AIC                            663.904
# Time:                        00:30:26   BIC                            668.779
# Sample:                    06-01-2018   HQIC                           665.256
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.066e+06   3.25e+04     32.834      0.000       1e+06    1.13e+06
# ar.L1.value     0.2162      0.201      1.076      0.282      -0.177       0.610
# ar.L2.value     0.0533      0.201      0.265      0.791      -0.340       0.447
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.7545           +0.0000j            2.7545            0.0000
# AR.2           -6.8081           +0.0000j            6.8081            0.5000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 120372.83440880505

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 8.092817643525482

# %%
plt.figure(figsize=(14,8))
pred_prices.plot(color='blue', linewidth=3)
manhattan_sales_data['value'].plot(color='orange')
plt.title('AR Model - Manhattan')
plt.xlabel('Year')
plt.ylabel('Dollars (Millions)')
plt.savefig('AR_Model_Manhattan.png')

# %% [markdown]
# #### AR Model - Brooklyn Median Asking Price <a id='bk_ar_model'></a>

# %%
stt.dickey_fuller_test(brooklyn_sales_data['value'])
# Out:
# Test statistic = -1.426
# P-value = 0.853
# Critical values :
# 	1%: -4.041963001634247 - The data is not stationary with 99% confidence
# 	5%: -3.4504426407047193 - The data is not stationary with 95% confidence
# 	10%: -3.1504645425245994 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(brooklyn_sales_data['value'].diff().diff()[2:])
# Out:
# Test statistic = -8.394
# P-value = 0.000
# Critical values :
# 	1%: -4.041963001634247 - The data is  stationary with 99% confidence
# 	5%: -3.4504426407047193 - The data is  stationary with 95% confidence
# 	10%: -3.1504645425245994 - The data is  stationary with 90% confidence

# %%
brooklyn_sales_data['value'].diff().diff()[2:].plot(figsize=(20,10), title='2nd Difference of Brooklyn Median Asking Price')

# %%
plot_pacf(brooklyn_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(brooklyn_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
testing_set_values = brooklyn_sales_data['value'][test_dates:]
testing_set = brooklyn_sales_data['value'][test_dates:]
training_set = brooklyn_sales_data['value'][training_dates_start:training_dates_end]

# %%
run_arma(training_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(2, 0)   Log Likelihood               -1157.802
# Method:                       css-mle   S.D. of innovations          22592.317
# Date:                Thu, 20 Aug 2020   AIC                           2323.604
# Time:                        00:39:02   BIC                           2334.065
# Sample:                    01-01-2010   HQIC                          2327.839
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        5.826e+05   1.27e+05      4.601      0.000    3.34e+05    8.31e+05
# ar.L1.value     0.5727      0.094      6.107      0.000       0.389       0.757
# ar.L2.value     0.4182      0.094      4.441      0.000       0.234       0.603
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0065           +0.0000j            1.0065            0.0000
# AR.2           -2.3760           +0.0000j            2.3760            0.5000
# -----------------------------------------------------------------------------
# """

# %%
run_arma(testing_set, 2, 0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   25
# Model:                     ARMA(2, 0)   Log Likelihood                -288.601
# Method:                       css-mle   S.D. of innovations          24871.317
# Date:                Thu, 20 Aug 2020   AIC                            585.203
# Time:                        00:39:05   BIC                            590.078
# Sample:                    06-01-2018   HQIC                           586.555
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        7.888e+05   8388.542     94.033      0.000    7.72e+05    8.05e+05
# ar.L1.value     0.1686      0.188      0.896      0.370      -0.200       0.537
# ar.L2.value     0.2510      0.198      1.265      0.206      -0.138       0.640
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.6882           +0.0000j            1.6882            0.0000
# AR.2           -2.3598           +0.0000j            2.3598            0.5000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 24900.126964911273

# %%
plt.figure(figsize=(20,10))
pred_prices.plot(color='red')
training_set.plot(color='blue')
brooklyn_sales_data['value'].plot(color='orange')

# %% [markdown]
# #### AR Model Bronx <a id = 'bx_ar_model'></a>

# %%
stt.dickey_fuller_test(bronx_sales_data['value'])
# Out:
# Test statistic = -1.561
# P-value = 0.807
# Critical values :
# 	1%: -4.039730383003206 - The data is not stationary with 99% confidence
# 	5%: -3.4493804768636473 - The data is not stationary with 95% confidence
# 	10%: -3.1498449798635657 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(bronx_sales_data['value'].diff()[1:])
# Out:
# Test statistic = -5.879
# P-value = 0.000
# Critical values :
# 	1%: -4.039730383003206 - The data is  stationary with 99% confidence
# 	5%: -3.4493804768636473 - The data is  stationary with 95% confidence
# 	10%: -3.1498449798635657 - The data is  stationary with 90% confidence

# %%
plot_pacf(bronx_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(bronx_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plt.figure(figsize=(14,8))
bronx_sales_data['value'].plot()
bronx_sales_data['value'].diff()[1:].plot()
plt.xlabel('Year')
plt.ylabel('Dollars')
plt.title('Bronx Housing Prices with Differentiation')
plt.savefig('bronx_housing.png')

# %%
testing_set_values = bronx_sales_data['value'][test_dates:]
testing_set = bronx_sales_data['value'][test_dates:]
training_set = bronx_sales_data['value'][training_dates_start:training_dates_end]

# %%
plot_pacf(bronx_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(bronx_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
run_arma(training_set, 1, 0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(1, 0)   Log Likelihood               -1176.604
# Method:                       css-mle   S.D. of innovations          27636.522
# Date:                Thu, 20 Aug 2020   AIC                           2359.208
# Time:                        00:40:03   BIC                           2367.054
# Sample:                    01-01-2010   HQIC                          2362.384
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         3.37e+05   9805.103     34.370      0.000    3.18e+05    3.56e+05
# ar.L1.value     0.7265      0.070     10.321      0.000       0.589       0.864
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3765           +0.0000j            1.3765            0.0000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(1,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 30306.212202923834

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 5.324099468171897

# %%
plt.figure(figsize=(20,10))
pred_prices.plot(color='blue', linewidth=3)
bronx_sales_data['value'].plot(color='black')
plt.xlabel('Year')
plt.ylabel('Dollars')
plt.title('AR Model - Bronx')
plt.savefig('AR_Model_Bronx.png')

# %% [markdown]
# ### AR Model - 2nd Order - Bronx

# %%
run_arma(training_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(2, 0)   Log Likelihood               -1169.492
# Method:                       css-mle   S.D. of innovations          25714.779
# Date:                Thu, 20 Aug 2020   AIC                           2346.985
# Time:                        00:42:36   BIC                           2357.445
# Sample:                    01-01-2010   HQIC                          2351.219
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         3.37e+05   1.46e+04     23.096      0.000    3.08e+05    3.66e+05
# ar.L1.value     0.4658      0.093      5.010      0.000       0.284       0.648
# ar.L2.value     0.3700      0.094      3.925      0.000       0.185       0.555
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1310           +0.0000j            1.1310            0.0000
# AR.2           -2.3899           +0.0000j            2.3899            0.5000
# -----------------------------------------------------------------------------
# """

# %%
run_arma(testing_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   25
# Model:                     ARMA(2, 0)   Log Likelihood                -292.624
# Method:                       css-mle   S.D. of innovations          29073.733
# Date:                Thu, 20 Aug 2020   AIC                            593.249
# Time:                        00:42:37   BIC                            598.124
# Sample:                    06-01-2018   HQIC                           594.601
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.609e+05   1.44e+04     31.965      0.000    4.33e+05    4.89e+05
# ar.L1.value     0.3999      0.195      2.052      0.040       0.018       0.782
# ar.L2.value     0.2295      0.200      1.150      0.250      -0.162       0.621
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3907           +0.0000j            1.3907            0.0000
# AR.2           -3.1336           +0.0000j            3.1336            0.5000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 29579.739868206718

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 5.072594556066539

# %%
plt.figure(figsize=(20,10))
pred_prices.plot(color='blue', linewidth=3)
bronx_sales_data['value'].plot(color='black')
plt.xlabel('Year')
plt.ylabel('Dollars')
plt.title('AR Model - Bronx')
plt.savefig('AR_Model_Bronx.png')

# %% [markdown]
# ### AR Model - Queens <a id=''queens_ar_model></a>

# %%
stt.dickey_fuller_test(queens_sales_data['value'])
# Out:
# Test statistic = -2.603
# P-value = 0.278
# Critical values :
# 	1%: -4.038307389431779 - The data is not stationary with 99% confidence
# 	5%: -3.448703208559121 - The data is not stationary with 95% confidence
# 	10%: -3.149449845280976 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(queens_sales_data['value'].diff()[1:])
# Out:
# Test statistic = -2.987
# P-value = 0.136
# Critical values :
# 	1%: -4.042734832692444 - The data is not stationary with 99% confidence
# 	5%: -3.4508097122615675 - The data is not stationary with 95% confidence
# 	10%: -3.1506786195618557 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(queens_sales_data['value'].diff().diff()[2:])
# Out:
# Test statistic = -7.983
# P-value = 0.000
# Critical values :
# 	1%: -4.042734832692444 - The data is  stationary with 99% confidence
# 	5%: -3.4508097122615675 - The data is  stationary with 95% confidence
# 	10%: -3.1506786195618557 - The data is  stationary with 90% confidence

# %%
plt.figure(figsize=(20,10))
queens_sales_data['value'].plot()
queens_sales_data['value'].diff()[1:].plot()
queens_sales_data['value'].diff().diff()[2:].plot()

# %%
testing_set_values = queens_sales_data['value'][test_dates:]
testing_set = queens_sales_data['value'][test_dates:]
training_set = queens_sales_data['value'][training_dates_start:training_dates_end]

# %%
plot_pacf(queens_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(queens_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
run_arma(training_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(2, 0)   Log Likelihood               -1110.756
# Method:                       css-mle   S.D. of innovations          14200.665
# Date:                Thu, 20 Aug 2020   AIC                           2229.511
# Time:                        00:43:50   BIC                           2239.972
# Sample:                    01-01-2010   HQIC                          2233.746
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.079e+05   6.93e+04      5.885      0.000    2.72e+05    5.44e+05
# ar.L1.value     0.7140      0.095      7.507      0.000       0.528       0.900
# ar.L2.value     0.2737      0.096      2.852      0.004       0.086       0.462
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0097           +0.0000j            1.0097            0.0000
# AR.2           -3.6184           +0.0000j            3.6184            0.5000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 19923.330462030655

# %%
plt.figure(figsize=(20,10))
pred_prices.plot(color='red')
training_set.plot(color='blue')
queens_sales_data['value'].plot(color='orange')

# %% [markdown]
# ### AR Model - Staten Island <a id='st_ar_model'></a>

# %%
stt.dickey_fuller_test(staten_island_sales_data['value'])
# Out:
# Test statistic = -2.405
# P-value = 0.377
# Critical values :
# 	1%: -4.034323572017774 - The data is not stationary with 99% confidence
# 	5%: -3.446805955734612 - The data is not stationary with 95% confidence
# 	10%: -3.1483426003846597 - The data is not stationary with 90% confidence

# %%
stt.dickey_fuller_test(staten_island_sales_data['value'].diff()[1:])
# Out:
# Test statistic = -8.206
# P-value = 0.000
# Critical values :
# 	1%: -4.035606405915461 - The data is  stationary with 99% confidence
# 	5%: -3.447417080919031 - The data is  stationary with 95% confidence
# 	10%: -3.148699310749108 - The data is  stationary with 90% confidence

# %%
testing_set_values = staten_island_sales_data['value'][test_dates:]
testing_set = staten_island_sales_data['value'][test_dates:]
training_set = staten_island_sales_data['value'][training_dates_start:training_dates_end]

# %%
plot_pacf(staten_island_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
plot_acf(staten_island_sales_data['value'], lags=20)
plt.figure(figsize=(20,10))

# %%
run_arma(training_set,2,0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:                     ARMA(2, 0)   Log Likelihood               -1108.282
# Method:                       css-mle   S.D. of innovations          13899.624
# Date:                Thu, 20 Aug 2020   AIC                           2224.563
# Time:                        00:44:44   BIC                           2235.024
# Sample:                    01-01-2010   HQIC                          2228.798
#                          - 05-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.052e+05   4.77e+04      8.497      0.000    3.12e+05    4.99e+05
# ar.L1.value     0.6165      0.093      6.661      0.000       0.435       0.798
# ar.L2.value     0.3607      0.094      3.841      0.000       0.177       0.545
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0170           +0.0000j            1.0170            0.0000
# AR.2           -2.7261           +0.0000j            2.7261            0.5000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,0))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 14942.486539680694

# %%
plt.figure(figsize=(20,10))
pred_prices.plot(color='red')
training_set.plot(color='blue')
staten_island_sales_data['value'].plot(color='orange')

# %% [markdown]
# ### ARMA Model <a id='arma_model'></a>

# %% [markdown]
# <p> Running Manhattan Models. Integrating both AR and MA components of testing.</p>

# %%
testing_set_values = manhattan_sales_data['value'][test_dates:]
testing_set = manhattan_sales_data['value'][test_dates:]
training_set = manhattan_sales_data['value'][training_dates_start:training_dates_end]

# %%
run_arma(manhattan_sales_data['value'],1,1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  126
# Model:                     ARMA(1, 1)   Log Likelihood               -1599.648
# Method:                       css-mle   S.D. of innovations          78473.032
# Date:                Thu, 20 Aug 2020   AIC                           3207.295
# Time:                        00:46:39   BIC                           3218.640
# Sample:                    01-01-2010   HQIC                          3211.904
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        9.375e+05   7.89e+04     11.879      0.000    7.83e+05    1.09e+06
# ar.L1.value     0.9734      0.025     38.239      0.000       0.924       1.023
# ma.L1.value    -0.6296      0.125     -5.043      0.000      -0.874      -0.385
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0273           +0.0000j            1.0273            0.0000
# MA.1            1.5883           +0.0000j            1.5883            0.0000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,5))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 105597.60506663151

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 7.053940927993806

# %%
plt.figure(figsize=(14,8))
pred_prices.plot()
manhattan_sales_data['value'].plot(color='orange')
plt.xlabel('Year')
plt.ylabel('Dollars (Millions)')
plt.title('ARMA - Manhattan')
plt.savefig('ARMA_Manhattan.png')

# %% [markdown]
# ### ARMA Model - Bronx <a id='arma_model_bronx'></a>

# %%
testing_set_values = bronx_sales_data['value'][test_dates:]
testing_set = bronx_sales_data['value'][test_dates:]
training_set = bronx_sales_data['value'][training_dates_start:training_dates_end]

# %%
run_arma(bronx_sales_data['value'].diff()[1:],1,1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  125
# Model:                     ARMA(1, 1)   Log Likelihood               -1438.495
# Method:                       css-mle   S.D. of innovations          23990.041
# Date:                Thu, 20 Aug 2020   AIC                           2884.990
# Time:                        00:49:29   BIC                           2896.303
# Sample:                    02-01-2010   HQIC                          2889.586
#                          - 06-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1487.7689    503.255      2.956      0.003     501.407    2474.131
# ar.L1.value    -0.0008      0.109     -0.007      0.994      -0.215       0.214
# ma.L1.value    -0.7718      0.065    -11.949      0.000      -0.898      -0.645
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1        -1254.0846           +0.0000j         1254.0846            0.5000
# MA.1            1.2956           +0.0000j            1.2956            0.0000
# -----------------------------------------------------------------------------
# """

# %%
mod_arma = ARMA(testing_set, order=(2,2))
res_arma = mod_arma.fit()
pred_prices = res_arma.predict()
np.sqrt(metrics.mean_squared_error(testing_set, pred_prices))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 29594.722992647126

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 5.233591042166998

# %%
plt.figure(figsize=(14,8))
pred_prices.plot()
bronx_sales_data['value'].plot(color='orange')
plt.xlabel('Year')
plt.ylabel('Dollars')
plt.title('ARMA - Bronx')
# Out:
# Text(0.5, 1.0, 'ARMA - Bronx')

# %% [markdown]
# ### ARIMA Models <a id='arima_models'></a>

# %% [markdown]
# #### Manhattan Median Asking Price

# %%
testing_set_values = manhattan_sales_data['value'][test_dates:]
testing_set = manhattan_sales_data['value'][test_dates:]
training_set = manhattan_sales_data['value'][training_dates_start:training_dates_end]

# %%
mod_arima = ARIMA(training_set, order=(2,1,1))
res_arima = mod_arima.fit()
res_arima.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.value   No. Observations:                  100
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1237.035
# Method:                       css-mle   S.D. of innovations          56757.837
# Date:                Thu, 20 Aug 2020   AIC                           2484.069
# Time:                        00:56:03   BIC                           2497.095
# Sample:                    02-01-2010   HQIC                          2489.341
#                          - 05-01-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          3349.1233   1039.095      3.223      0.001    1312.535    5385.712
# ar.L1.D.value     0.2342      0.122      1.915      0.056      -0.006       0.474
# ar.L2.D.value     0.1329      0.115      1.158      0.247      -0.092       0.358
# ma.L1.D.value    -0.8958      0.069    -13.033      0.000      -1.030      -0.761
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.0001           +0.0000j            2.0001            0.0000
# AR.2           -3.7629           +0.0000j            3.7629            0.5000
# MA.1            1.1164           +0.0000j            1.1164            0.0000
# -----------------------------------------------------------------------------
# """

# %%
model = ARIMA(testing_set, order=(3,0,4))
model_fit = model.fit()
pred_prices = model_fit.predict()
print(np.sqrt(metrics.mean_squared_error(testing_set, pred_prices)))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 106578.2445988598

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 6.764405228229614

# %%
plt.figure(figsize=(14,8))
pred_prices.plot(color='red')
manhattan_sales_data['value'].plot(color='orange')
plt.title('ARIMA Model - Manhattan Prediction')
plt.xlabel('Year')
plt.ylabel('Price (Millions)')
# Out:
# Text(0, 0.5, 'Price (Millions)')

# %% [markdown]
# ### Bronx ARIMA <a id='bronx_arima'></a>

# %%
testing_set_values = bronx_sales_data['value'][test_dates:]
testing_set = bronx_sales_data['value'][test_dates:]
training_set = bronx_sales_data['value'][training_dates_start:training_dates_end]

# %%
mod_arima = ARIMA(training_set, order=(2,1,1))
res_arima = mod_arima.fit()
res_arima.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.value   No. Observations:                  100
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1144.604
# Method:                       css-mle   S.D. of innovations          22509.585
# Date:                Thu, 20 Aug 2020   AIC                           2299.208
# Time:                        00:58:13   BIC                           2312.234
# Sample:                    02-01-2010   HQIC                          2304.480
#                          - 05-01-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           996.3383    530.439      1.878      0.060     -43.303    2035.980
# ar.L1.D.value    -0.1264      0.135     -0.939      0.348      -0.390       0.138
# ar.L2.D.value    -0.1839      0.122     -1.504      0.132      -0.423       0.056
# ma.L1.D.value    -0.6997      0.106     -6.612      0.000      -0.907      -0.492
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.3438           -2.3067j            2.3322           -0.2735
# AR.2           -0.3438           +2.3067j            2.3322            0.2735
# MA.1            1.4291           +0.0000j            1.4291            0.0000
# -----------------------------------------------------------------------------
# """

# %%
model = ARIMA(testing_set, order=(3,0,2))
model_fit = model.fit()
pred_prices = model_fit.predict()
print(np.sqrt(metrics.mean_squared_error(testing_set, pred_prices)))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 26285.94410281217

# %%
pm.metrics.smape(testing_set, pred_prices)
# Out:
# 4.545643124812682

# %%
plt.figure(figsize=(14,8))
pred_prices.plot(color='blue', linewidth=3)
bronx_sales_data['value'].plot(color='black')
plt.title('ARIMA Model - Bronx Prediction')
plt.xlabel('Year')

# %% [markdown]
# ### AUTO ARIMA Modeling <a id='auto_arima'></a>

# %% [markdown]
# #### Manhattan Sales Data

# %%
train, test = train_test_split(manhattan_sales_data['value'], train_size=101)

# %%
model = pm.auto_arima(train, m=12, start_d=0, start_p=1, start_q=1, d=1, max_d=2, max_p=2, max_q=3, suppress_warnings=True)

# %%
forecasts = model.predict(test.shape[0])

# %%
new_index = pd.date_range(start='2018-06-01', end='2020-06-01', freq='MS')

# %%
result_df = pd.DataFrame(index=new_index)

# %%
result_df['value'] = forecasts

# %%
plt.figure(figsize=(14,8))
plt.plot(result_df['value'], c='red')
plt.plot(manhattan_sales_data['value'], c='orange')
plt.title('AUTO ARIMA - Manhattan')
plt.xlabel('Year')
plt.ylabel('Dollar (Millions)')
plt.savefig('AUTO_ARIMA_Manhattan.png')

# %%
np.sqrt(metrics.mean_squared_error(test, forecasts))
# Out:
# 120355.24854723277

# %%
pm.metrics.smape(test, forecasts)
# Out:
# 7.733257097198616

# %% [markdown]
# #### Bronx Sales Auto Arima

# %%
bronx_train, bronx_test = train_test_split(bronx_sales_data['value'], train_size=101)

# %%
bronx_model = pm.auto_arima(bronx_train, m=12, start_p=1, start_q=1, d=1, D=1, suppress_warnings=True)

# %%
bronx_forecasts = bronx_model.predict(bronx_test.shape[0])

# %%
bronx_result_df = pd.DataFrame(index=pd.date_range(start='2018-06-01', end='2020-06-01', freq='MS'))

# %%
bronx_result_df['value'] = bronx_forecasts

# %%
plt.figure(figsize=(14,8))
plt.plot(bronx_result_df['value'], c='blue', linewidth=3)
plt.plot(bronx_sales_data['value'], c='black')
plt.title('AUTO ARIMA - Bronx')
plt.xlabel('Year')
plt.ylabel('Dollars')
# Out:
# Text(0, 0.5, 'Dollars')

# %%
np.sqrt(metrics.mean_squared_error(bronx_test, bronx_forecasts))
# Out:
# 29444.452899934728

# %%
pm.metrics.smape(bronx_test, bronx_forecasts)
# Out:
# 5.001951209996076

# %% [markdown]
# #### Staten Island ARIMA

# %%
si_train, si_test = train_test_split(staten_island_sales_data['value'], train_size=101)

# %%
si_model = pm.auto_arima(si_train, m=12, start_d=0, D=1, start_p=1, start_q=1, d=1, max_d=2, max_p=2, max_q=3, suppress_warnings=True)

# %%
si_forecasts = si_model.predict(si_test.shape[0])

# %%
si_result_df = pd.DataFrame(index=new_index)

# %%
si_result_df['value'] = si_forecasts

# %%
plt.figure(figsize=(20,10))
plt.plot(si_train, c='blue')
plt.plot(si_result_df['value'], c='red')
plt.plot(staten_island_sales_data['value'])
plt.show()

# %%
np.sqrt(metrics.mean_squared_error(si_test, si_forecasts))
# Out:
# 38020.73212955251

# %%
pm.metrics.smape(si_test, si_forecasts)
# Out:
# 6.216975240633258

# %% [markdown]
# #### Brooklyn ARIMA

# %%
bk_train, bk_test = train_test_split(brooklyn_sales_data['value'], train_size=101)

# %%
bk_model = pm.auto_arima(bk_train, start_p=1, start_q=1, d=1, D=1,m=12, suppress_warnings=True)

# %%
bk_forecasts = bk_model.predict(bk_test.shape[0])

# %%
bk_result_df = pd.DataFrame(index=new_index)

# %%
bk_result_df['value'] = bk_forecasts

# %%
plt.figure(figsize=(20,10))
plt.plot(bk_train, c='blue')
plt.plot(bk_result_df['value'], c='red')
plt.plot(brooklyn_sales_data['value'])
plt.show()

# %%
np.sqrt(metrics.mean_squared_error(bk_test, bk_forecasts))
# Out:
# 54114.461852664885

# %%
pm.metrics.smape(bk_test, bk_forecasts)
# Out:
# 5.459495388071567

# %% [markdown]
# ### SARIMAX Model

# %% [markdown]
# #### Manhattan Model

# %%
testing_set_values = manhattan_sales_data['value'][test_dates:]
testing_set = manhattan_sales_data['value'][test_dates:]
training_set = manhattan_sales_data['value'][training_dates_start:training_dates_end]

mod = sm.tsa.statespace.SARIMAX(endog = training_set, trend='ctt', order=(4,1,3))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
res = mod.fit(disp=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:               SARIMAX(4, 1, 3)   Log Likelihood               -1246.305
# Date:                Thu, 20 Aug 2020   AIC                           2514.609
# Time:                        01:44:27   BIC                           2543.266
# Sample:                    01-01-2010   HQIC                          2526.207
#                          - 05-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1.526e+04     98.280   -155.278      0.000   -1.55e+04   -1.51e+04
# drift       1323.0022   2789.816      0.474      0.635   -4144.936    6790.941
# trend.2      -12.7763     35.032     -0.365      0.715     -81.437      55.884
# ar.L1         -2.5177      0.473     -5.322      0.000      -3.445      -1.590
# ar.L2         -2.6625      0.841     -3.166      0.002      -4.311      -1.014
# ar.L3         -1.2626      0.664     -1.901      0.057      -2.564       0.039
# ar.L4         -0.1747      0.157     -1.115      0.265      -0.482       0.132
# ma.L1          2.3442      0.472      4.970      0.000       1.420       3.269
# ma.L2          2.2264      0.732      3.041      0.002       0.792       3.661
# ma.L3          0.7955      0.460      1.731      0.083      -0.105       1.696
# sigma2      3.154e+09      0.001   4.35e+12      0.000    3.15e+09    3.15e+09
# ===================================================================================
# Ljung-Box (Q):                       45.84   Jarque-Bera (JB):                 0.02
# Prob(Q):                              0.24   Prob(JB):                         0.99
# Heteroskedasticity (H):               1.67   Skew:                            -0.03
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.44e+29. Standard errors may be unstable.
# """

# %%
start_date = testing_set.index[0]
end_date = testing_set.index[-1]

# %%
predictions = res.predict(start=start_date, end=end_date)

# %%
plt.figure(figsize=(14,8))
manhattan_sales_data['value'].plot()
predictions.plot()

# %%
np.sqrt(metrics.mean_squared_error(testing_set, predictions))
# Out:
# 131615.78508938907

# %%
pm.metrics.smape(testing_set, predictions)
# Out:
# 7.822768048498804

# %% [markdown]
# #### Bronx Sarimax

# %%
testing_set = bronx_sales_data['value'][test_dates:]
training_set = bronx_sales_data['value'][training_dates_start:training_dates_end]

mod = sm.tsa.statespace.SARIMAX(endog = training_set, trend='ct', order=(2,2,2))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
res = mod.fit(disp=False)
res.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  101
# Model:               SARIMAX(2, 2, 2)   Log Likelihood               -1175.081
# Date:                Thu, 20 Aug 2020   AIC                           2364.161
# Time:                        01:45:24   BIC                           2382.327
# Sample:                    01-01-2010   HQIC                          2371.511
#                          - 05-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -377.6465      0.097  -3877.714      0.000    -377.837    -377.456
# drift          4.1723      5.323      0.784      0.433      -6.261      14.606
# ar.L1         -0.9980      0.031    -32.552      0.000      -1.058      -0.938
# ar.L2          0.0020      0.038      0.054      0.957      -0.073       0.077
# ma.L1         -0.0001      2.220  -6.25e-05      1.000      -4.352       4.352
# ma.L2         -0.9998      0.084    -11.895      0.000      -1.165      -0.835
# sigma2      8.225e+08   2.75e-09   2.99e+17      0.000    8.22e+08    8.22e+08
# ===================================================================================
# Ljung-Box (Q):                       44.17   Jarque-Bera (JB):                29.73
# Prob(Q):                              0.30   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                            -0.41
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.49e+35. Standard errors may be unstable.
# """

# %%
predictions = res.predict(start=start_date, end=end_date)

# %%
plt.figure(figsize=(14,8))
bronx_sales_data['value'].plot()
predictions.plot()

# %%
np.sqrt(metrics.mean_squared_error(testing_set, predictions))
# Out:
# 29468.14429687212

# %%
pm.metrics.smape(testing_set, predictions)
# Out:
# 4.798333874435486

# %% [markdown]
# ### LSTM Model <a id='lstm_model'></a>

# %% [markdown]
# ### Manhattan LSTM Model <a id='manhattan_lstm'></a>

# %%
msd = manhattan_sales_data['value'].values

# %%
msd = msd.astype('float32')

# %%
msd = np.reshape(msd, (-1, 1))

# %%
scaler = StandardScaler()
msd = scaler.fit_transform(msd)
train_size = int(len(msd) * 0.80)
test_size = len(msd) - train_size
train, test = msd[0:train_size,:], msd[train_size:len(msd),:]

# %%
look_back = 3
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(300, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 286ms/step - loss: 0.8981 - val_loss: 1.7555
# Epoch 2/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.8306 - val_loss: 1.6724
# Epoch 3/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7744 - val_loss: 1.5919
# Epoch 4/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7221 - val_loss: 1.5153
# Epoch 5/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6687 - val_loss: 1.4428
# Epoch 6/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6202 - val_loss: 1.3747
# Epoch 7/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5750 - val_loss: 1.3108
# Epoch 8/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5342 - val_loss: 1.2512
# Epoch 9/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4904 - val_loss: 1.1959
# Epoch 10/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4557 - val_loss: 1.1450
# Epoch 11/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4189 - val_loss: 1.0987
# Epoch 12/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3839 - val_loss: 1.0569
# Epoch 13/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3530 - val_loss: 1.0199
# Epoch 14/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3270 - val_loss: 0.9878
# Epoch 15/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3017 - val_loss: 0.9607
# Epoch 16/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2758 - val_loss: 0.9387
# Epoch 17/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2599 - val_loss: 0.9218
# Epoch 18/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2360 - val_loss: 0.9097
# Epoch 19/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2215 - val_loss: 0.9023
# Epoch 20/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2133 - val_loss: 0.8989
# Epoch 21/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1988 - val_loss: 0.8990
# Epoch 22/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2012 - val_loss: 0.9018
# Epoch 23/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1910 - val_loss: 0.9062
# Epoch 24/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1903 - val_loss: 0.9114
# Epoch 25/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1829 - val_loss: 0.9166
# Epoch 26/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1814 - val_loss: 0.9213
# Epoch 27/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1804 - val_loss: 0.9248
# Epoch 28/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1866 - val_loss: 0.9269
# Epoch 29/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1812 - val_loss: 0.9272
# Epoch 30/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1798 - val_loss: 0.9257
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_42 (LSTM)               (None, 300)               364800
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 365,101
# Trainable params: 365,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 48533.207
# Train Root Mean Squared Error: 60342.855
# Test Mean Absolute Error: 99522.195
# Test Root Mean Squared Error: 136129.88

# %%
# aa=[x for x in range(22)]
plt.figure(figsize=(8,4))
plt.plot(Y_test[0][:22], marker='.', label="actual")
plt.plot(test_predict[:,0][:22], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()

# %%
res = pd.DataFrame(index=pd.date_range(start='2018-09-01', periods=22, freq='MS'))

# %%
price_list = []
for i in test_predict[:,0][:22]:
    price_list.append(i)

# %%
res['value'] = price_list

# %%
manhattan_sales_data['value'].plot()
res['value'].plot(figsize=(14,7))

# %%
pm.metrics.smape(Y_test[0], test_predict[:,0])
# Out:
# 8.87803384433294

# %% [markdown]
# ### Bronx LSTM <a id='bronx_lstm'></a>

# %%
bsd = bronx_sales_data['value'].values
bsd = bsd.astype('float32')
bsd = np.reshape(bsd, (-1, 1))

# %%
scaler = StandardScaler()
bsd = scaler.fit_transform(bsd)
train_size = int(len(bsd) * 0.80)
test_size = len(bsd) - train_size
train, test = bsd[0:train_size,:], bsd[train_size:len(bsd),:]

# %%
look_back = 3
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(400, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 277ms/step - loss: 0.5732 - val_loss: 2.9081
# Epoch 2/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5250 - val_loss: 2.7229
# Epoch 3/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4849 - val_loss: 2.5425
# Epoch 4/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4486 - val_loss: 2.3675
# Epoch 5/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.4140 - val_loss: 2.1984
# Epoch 6/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3790 - val_loss: 2.0353
# Epoch 7/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3532 - val_loss: 1.8783
# Epoch 8/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3234 - val_loss: 1.7273
# Epoch 9/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2977 - val_loss: 1.5826
# Epoch 10/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2691 - val_loss: 1.4442
# Epoch 11/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2490 - val_loss: 1.3124
# Epoch 12/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2293 - val_loss: 1.1876
# Epoch 13/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2103 - val_loss: 1.0703
# Epoch 14/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1980 - val_loss: 0.9610
# Epoch 15/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1852 - val_loss: 0.8601
# Epoch 16/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1735 - val_loss: 0.7679
# Epoch 17/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1682 - val_loss: 0.6849
# Epoch 18/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1614 - val_loss: 0.6114
# Epoch 19/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1565 - val_loss: 0.5470
# Epoch 20/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1549 - val_loss: 0.4917
# Epoch 21/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1522 - val_loss: 0.4450
# Epoch 22/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1497 - val_loss: 0.4062
# Epoch 23/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1529 - val_loss: 0.3747
# Epoch 24/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1500 - val_loss: 0.3495
# Epoch 25/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1507 - val_loss: 0.3298
# Epoch 26/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1535 - val_loss: 0.3147
# Epoch 27/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1512 - val_loss: 0.3030
# Epoch 28/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1525 - val_loss: 0.2943
# Epoch 29/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1482 - val_loss: 0.2876
# Epoch 30/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1486 - val_loss: 0.2825
# Epoch 31/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1500 - val_loss: 0.2785
# Epoch 32/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1498 - val_loss: 0.2752
# Epoch 33/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1508 - val_loss: 0.2726
# Epoch 34/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1477 - val_loss: 0.2703
# Epoch 35/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1486 - val_loss: 0.2683
# Epoch 36/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1496 - val_loss: 0.2664
# Epoch 37/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1454 - val_loss: 0.2647
# Epoch 38/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1459 - val_loss: 0.2631
# Epoch 39/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1449 - val_loss: 0.2617
# Epoch 40/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1501 - val_loss: 0.2605
# Epoch 41/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1464 - val_loss: 0.2596
# Epoch 42/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1448 - val_loss: 0.2590
# Epoch 43/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1477 - val_loss: 0.2589
# Epoch 44/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1469 - val_loss: 0.2591
# Epoch 45/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1434 - val_loss: 0.2596
# Epoch 46/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1454 - val_loss: 0.2605
# Epoch 47/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1443 - val_loss: 0.2617
# Epoch 48/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1451 - val_loss: 0.2631
# Epoch 49/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1446 - val_loss: 0.2647
# Epoch 50/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1443 - val_loss: 0.2665
# Epoch 51/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1431 - val_loss: 0.2684
# Epoch 52/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1437 - val_loss: 0.2704
# Epoch 53/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1447 - val_loss: 0.2724
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_43 (LSTM)               (None, 400)               646400
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 401
# =================================================================
# Total params: 646,801
# Trainable params: 646,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 17306.047
# Train Root Mean Squared Error: 23824.832
# Test Mean Absolute Error: 27511.887
# Test Root Mean Squared Error: 32796.85

# %%
new_res = pd.DataFrame(index=pd.date_range(start='2018-09-01', periods=22, freq='MS'))

# %%
price_list = []
for i in test_predict[:,0][:22]:
    price_list.append(i)

# %%
new_res['value'] = price_list
bronx_sales_data['value'].plot()
new_res['value'].plot(figsize=(14,7))

# %%
pm.metrics.smape(Y_test[0], test_predict[:,0])
# Out:
# 5.85361000704846

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ### Manhattan Sales & Manhattan Housing Sales Count

# %%
man_sv_diff = manhattan_sales_volume['value']
man_sd_diff = manhattan_sales_data['value']
multi_diff = pd.DataFrame(index=man_sv_diff.index)

# %%
multi_diff['sales_volume'] = man_sv_diff
multi_diff['sales_data'] = man_sd_diff

# %%
scaler = StandardScaler()
multi_diff = scaler.fit_transform(multi_diff)
train_size = int(len(multi_diff) * 0.80)
test_size = len(multi_diff) - train_size
train, test = multi_diff[0:train_size,:], multi_diff[train_size:len(multi_diff),:]

# %%
look_back = 3
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(400, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 283ms/step - loss: 0.9032 - val_loss: 1.3007
# Epoch 2/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8683 - val_loss: 1.2730
# Epoch 3/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8492 - val_loss: 1.2462
# Epoch 4/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.8166 - val_loss: 1.2205
# Epoch 5/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7956 - val_loss: 1.1958
# Epoch 6/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7781 - val_loss: 1.1723
# Epoch 7/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7621 - val_loss: 1.1499
# Epoch 8/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7455 - val_loss: 1.1288
# Epoch 9/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7308 - val_loss: 1.1090
# Epoch 10/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7221 - val_loss: 1.0905
# Epoch 11/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7097 - val_loss: 1.0732
# Epoch 12/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7001 - val_loss: 1.0571
# Epoch 13/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6922 - val_loss: 1.0422
# Epoch 14/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6883 - val_loss: 1.0283
# Epoch 15/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6810 - val_loss: 1.0153
# Epoch 16/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6704 - val_loss: 1.0031
# Epoch 17/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6678 - val_loss: 0.9919
# Epoch 18/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6618 - val_loss: 0.9814
# Epoch 19/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6559 - val_loss: 0.9718
# Epoch 20/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6520 - val_loss: 0.9630
# Epoch 21/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6500 - val_loss: 0.9549
# Epoch 22/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6468 - val_loss: 0.9475
# Epoch 23/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6363 - val_loss: 0.9406
# Epoch 24/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6476 - val_loss: 0.9343
# Epoch 25/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6382 - val_loss: 0.9286
# Epoch 26/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6394 - val_loss: 0.9234
# Epoch 27/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6360 - val_loss: 0.9186
# Epoch 28/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6314 - val_loss: 0.9143
# Epoch 29/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6357 - val_loss: 0.9102
# Epoch 30/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6310 - val_loss: 0.9066
# Epoch 31/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6260 - val_loss: 0.9030
# Epoch 32/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6289 - val_loss: 0.8998
# Epoch 33/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6215 - val_loss: 0.8967
# Epoch 34/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6257 - val_loss: 0.8939
# Epoch 35/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6267 - val_loss: 0.8914
# Epoch 36/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6293 - val_loss: 0.8893
# Epoch 37/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6210 - val_loss: 0.8874
# Epoch 38/200
# 2/2 [==============================] - ETA: 0s - loss: 0.678 - 0s 38ms/step - loss: 0.6256 - val_loss: 0.8856
# Epoch 39/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6266 - val_loss: 0.8842
# Epoch 40/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6199 - val_loss: 0.8831
# Epoch 41/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6236 - val_loss: 0.8822
# Epoch 42/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6255 - val_loss: 0.8815
# Epoch 43/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6247 - val_loss: 0.8808
# Epoch 44/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6225 - val_loss: 0.8802
# Epoch 45/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6259 - val_loss: 0.8797
# Epoch 46/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6281 - val_loss: 0.8795
# Epoch 47/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6187 - val_loss: 0.8794
# Epoch 48/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6216 - val_loss: 0.8792
# Epoch 49/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6250 - val_loss: 0.8790
# Epoch 50/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6253 - val_loss: 0.8789
# Epoch 51/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6171 - val_loss: 0.8787
# Epoch 52/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6236 - val_loss: 0.8785
# Epoch 53/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6247 - val_loss: 0.8783
# Epoch 54/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6250 - val_loss: 0.8782
# Epoch 55/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6208 - val_loss: 0.8780
# Epoch 56/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6188 - val_loss: 0.8776
# Epoch 57/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6183 - val_loss: 0.8772
# Epoch 58/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6163 - val_loss: 0.8768
# Epoch 59/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6214 - val_loss: 0.8764
# Epoch 60/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6252 - val_loss: 0.8760
# Epoch 61/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6145 - val_loss: 0.8759
# Epoch 62/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6199 - val_loss: 0.8758
# Epoch 63/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6171 - val_loss: 0.8756
# Epoch 64/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6193 - val_loss: 0.8754
# Epoch 65/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6142 - val_loss: 0.8752
# Epoch 66/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6154 - val_loss: 0.8751
# Epoch 67/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6172 - val_loss: 0.8748
# Epoch 68/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6193 - val_loss: 0.8745
# Epoch 69/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6169 - val_loss: 0.8740
# Epoch 70/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6179 - val_loss: 0.8734
# Epoch 71/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6130 - val_loss: 0.8727
# Epoch 72/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6148 - val_loss: 0.8721
# Epoch 73/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6171 - val_loss: 0.8716
# Epoch 74/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6132 - val_loss: 0.8712
# Epoch 75/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6212 - val_loss: 0.8709
# Epoch 76/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6173 - val_loss: 0.8708
# Epoch 77/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6144 - val_loss: 0.8706
# Epoch 78/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6114 - val_loss: 0.8704
# Epoch 79/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6151 - val_loss: 0.8700
# Epoch 80/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6110 - val_loss: 0.8694
# Epoch 81/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6118 - val_loss: 0.8688
# Epoch 82/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6076 - val_loss: 0.8681
# Epoch 83/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6090 - val_loss: 0.8674
# Epoch 84/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6119 - val_loss: 0.8668
# Epoch 85/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6073 - val_loss: 0.8660
# Epoch 86/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6109 - val_loss: 0.8654
# Epoch 87/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6111 - val_loss: 0.8647
# Epoch 88/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6073 - val_loss: 0.8639
# Epoch 89/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6101 - val_loss: 0.8633
# Epoch 90/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6106 - val_loss: 0.8627
# Epoch 91/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6091 - val_loss: 0.8621
# Epoch 92/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6052 - val_loss: 0.8614
# Epoch 93/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6039 - val_loss: 0.8607
# Epoch 94/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6068 - val_loss: 0.8601
# Epoch 95/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6046 - val_loss: 0.8593
# Epoch 96/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6040 - val_loss: 0.8584
# Epoch 97/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6060 - val_loss: 0.8578
# Epoch 98/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6048 - val_loss: 0.8573
# Epoch 99/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6007 - val_loss: 0.8565
# Epoch 100/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6014 - val_loss: 0.8555
# Epoch 101/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6033 - val_loss: 0.8542
# Epoch 102/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5992 - val_loss: 0.8530
# Epoch 103/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6019 - val_loss: 0.8519
# Epoch 104/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5998 - val_loss: 0.8510
# Epoch 105/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6019 - val_loss: 0.8501
# Epoch 106/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5954 - val_loss: 0.8491
# Epoch 107/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5977 - val_loss: 0.8483
# Epoch 108/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5943 - val_loss: 0.8474
# Epoch 109/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6008 - val_loss: 0.8466
# Epoch 110/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6016 - val_loss: 0.8460
# Epoch 111/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5971 - val_loss: 0.8456
# Epoch 112/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5981 - val_loss: 0.8452
# Epoch 113/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5949 - val_loss: 0.8450
# Epoch 114/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5907 - val_loss: 0.8447
# Epoch 115/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5973 - val_loss: 0.8443
# Epoch 116/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5906 - val_loss: 0.8439
# Epoch 117/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5922 - val_loss: 0.8434
# Epoch 118/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5885 - val_loss: 0.8432
# Epoch 119/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5907 - val_loss: 0.8424
# Epoch 120/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5881 - val_loss: 0.8414
# Epoch 121/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5854 - val_loss: 0.8402
# Epoch 122/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5853 - val_loss: 0.8391
# Epoch 123/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5838 - val_loss: 0.8382
# Epoch 124/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5845 - val_loss: 0.8373
# Epoch 125/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5870 - val_loss: 0.8362
# Epoch 126/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5895 - val_loss: 0.8355
# Epoch 127/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5826 - val_loss: 0.8349
# Epoch 128/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5827 - val_loss: 0.8342
# Epoch 129/200
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5812 - val_loss: 0.8334
# Epoch 130/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5819 - val_loss: 0.8327
# Epoch 131/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5811 - val_loss: 0.8321
# Epoch 132/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5802 - val_loss: 0.8314
# Epoch 133/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5809 - val_loss: 0.8309
# Epoch 134/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5827 - val_loss: 0.8303
# Epoch 135/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5718 - val_loss: 0.8300
# Epoch 136/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5785 - val_loss: 0.8294
# Epoch 137/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5791 - val_loss: 0.8287
# Epoch 138/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5758 - val_loss: 0.8284
# Epoch 139/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5791 - val_loss: 0.8281
# Epoch 140/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5780 - val_loss: 0.8281
# Epoch 141/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5686 - val_loss: 0.8280
# Epoch 142/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5833 - val_loss: 0.8276
# Epoch 143/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5824 - val_loss: 0.8272
# Epoch 144/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5731 - val_loss: 0.8266
# Epoch 145/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5745 - val_loss: 0.8261
# Epoch 146/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5712 - val_loss: 0.8257
# Epoch 147/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5763 - val_loss: 0.8255
# Epoch 148/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5709 - val_loss: 0.8252
# Epoch 149/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5699 - val_loss: 0.8253
# Epoch 150/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5680 - val_loss: 0.8255
# Epoch 151/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5761 - val_loss: 0.8256
# Epoch 152/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5631 - val_loss: 0.8254
# Epoch 153/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5667 - val_loss: 0.8249
# Epoch 154/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5714 - val_loss: 0.8245
# Epoch 155/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5703 - val_loss: 0.8248
# Epoch 156/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5624 - val_loss: 0.8251
# Epoch 157/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5590 - val_loss: 0.8248
# Epoch 158/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5636 - val_loss: 0.8246
# Epoch 159/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5685 - val_loss: 0.8242
# Epoch 160/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5680 - val_loss: 0.8239
# Epoch 161/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5673 - val_loss: 0.8239
# Epoch 162/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5618 - val_loss: 0.8238
# Epoch 163/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5581 - val_loss: 0.8241
# Epoch 164/200
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6091
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.151008). Check your callbacks.
# 2/2 [==============================] - 0s 132ms/step - loss: 0.5691 - val_loss: 0.8242
# Epoch 165/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5590 - val_loss: 0.8240
# Epoch 166/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5674 - val_loss: 0.8240
# Epoch 167/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5651 - val_loss: 0.8238
# Epoch 168/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5690 - val_loss: 0.8234
# Epoch 169/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5595 - val_loss: 0.8233
# Epoch 170/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5559 - val_loss: 0.8229
# Epoch 171/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5614 - val_loss: 0.8224
# Epoch 172/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5613 - val_loss: 0.8223
# Epoch 173/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5624 - val_loss: 0.8222
# Epoch 174/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5674 - val_loss: 0.8223
# Epoch 175/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5580 - val_loss: 0.8221
# Epoch 176/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5542 - val_loss: 0.8215
# Epoch 177/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5647 - val_loss: 0.8205
# Epoch 178/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5644 - val_loss: 0.8198
# Epoch 179/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5584 - val_loss: 0.8192
# Epoch 180/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5548 - val_loss: 0.8185
# Epoch 181/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5569 - val_loss: 0.8179
# Epoch 182/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5640 - val_loss: 0.8174
# Epoch 183/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5518 - val_loss: 0.8172
# Epoch 184/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5525 - val_loss: 0.8169
# Epoch 185/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5563 - val_loss: 0.8166
# Epoch 186/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5653 - val_loss: 0.8164
# Epoch 187/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5539 - val_loss: 0.8163
# Epoch 188/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5597 - val_loss: 0.8162
# Epoch 189/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5590 - val_loss: 0.8161
# Epoch 190/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5516 - val_loss: 0.8159
# Epoch 191/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5662 - val_loss: 0.8160
# Epoch 192/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5566 - val_loss: 0.8165
# Epoch 193/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5611 - val_loss: 0.8169
# Epoch 194/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5656 - val_loss: 0.8171
# Epoch 195/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5621 - val_loss: 0.8174
# Epoch 196/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5513 - val_loss: 0.8171
# Epoch 197/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5559 - val_loss: 0.8166
# Epoch 198/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5642 - val_loss: 0.8157
# Epoch 199/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5606 - val_loss: 0.8148
# Epoch 200/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5597 - val_loss: 0.8137
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_37 (LSTM)               (None, 400)               646400
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 401
# =================================================================
# Total params: 646,801
# Trainable params: 646,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train_predict = model.predict(X_train)
# test_predict = model.predict(X_test)
# # invert predictions
# train_predict = scaler.inverse_transform(train_predict)
# # Y_train = scaler.inverse_transform([Y_train])
# # test_predict = scaler.inverse_transform(test_predict)
# # Y_test = scaler.inverse_transform([Y_test])
# # print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
# # print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
# # print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
# # print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))

# %% [markdown]
# ### Conclusion <a id='conclusion'></a>
